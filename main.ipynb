# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install deepface
from deepface import DeepFace
import matplotlib.pyplot as plt
import pandas as pd

# %%
img1_path = "/content/drive/MyDrive/Colab Notebooks/Emma-Stone-1.jpg"
img2_path = "/content/drive/MyDrive/Colab Notebooks/Emma-stone-2.avif"
img3_path = "/content/drive/MyDrive/Colab Notebooks/jennifer-lawrence.jpg"

# %%
img1 = plt.imread(img1_path)
img2 = plt.imread(img2_path)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.title('Image 1')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img2)
plt.title('Image 2')
plt.axis('off')

plt.show()

# %%
model_name = "Facenet"

# %%
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name= model_name)

# %%
resp
# Out:
# {'verified': True,
#  'distance': 0.305347,
#  'threshold': 0.4,
#  'confidence': 63.54,
#  'model': 'Facenet',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 251,
#    'y': 252,
#    'w': 669,
#    'h': 669,
#    'left_eye': (694, 528),
#    'right_eye': (440, 523)},
#   'img2': {'x': 197,
#    'y': 204,
#    'w': 153,
#    'h': 153,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 1.98}

# %%
model_name = "ArcFace"

# %%
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name= model_name)
# Out:
# 25-12-07 18:11:06 - 🔗 arcface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5 to /root/.deepface/weights/arcface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /root/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:03<00:00, 35.0MB/s]

# %%
resp
# Out:
# {'verified': True,
#  'distance': 0.367941,
#  'threshold': 0.68,
#  'confidence': 76.82,
#  'model': 'ArcFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 251,
#    'y': 252,
#    'w': 669,
#    'h': 669,
#    'left_eye': (694, 528),
#    'right_eye': (440, 523)},
#   'img2': {'x': 197,
#    'y': 204,
#    'w': 153,
#    'h': 153,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 8.95}

# %%
model_name = "OpenFace"

# %%
resp = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name= model_name)
# Out:
# 25-12-07 18:11:44 - 🔗 openface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5 to /root/.deepface/weights/openface_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/openface_weights.h5
# To: /root/.deepface/weights/openface_weights.h5
# 100%|██████████| 15.3M/15.3M [00:01<00:00, 12.2MB/s]

# %%
resp
# Out:
# {'verified': False,
#  'distance': 0.131419,
#  'threshold': 0.1,
#  'confidence': 7.92,
#  'model': 'OpenFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 251,
#    'y': 252,
#    'w': 669,
#    'h': 669,
#    'left_eye': (694, 528),
#    'right_eye': (440, 523)},
#   'img2': {'x': 197,
#    'y': 204,
#    'w': 153,
#    'h': 153,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 6.13}

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
df = DeepFace.find(img_path = "Emma-Stone-1.jpg", db_path= "/content/drive/MyDrive/Colab Notebooks")
# Out:
# 25-12-07 18:25:12 - Found 12 newly added image(s), 0 removed image(s), 0 replaced image(s).
# Finding representations: 100%|██████████| 12/12 [00:24<00:00,  2.05s/it]
# 25-12-07 18:25:36 - There are now 15 representations in ds_model_vggface_detector_opencv_aligned_normalization_base_expand_0.pkl
# 25-12-07 18:25:37 - Searching Emma-Stone-1.jpg in 15 length datastore
# 25-12-07 18:25:38 - find function duration 34.54848766326904 seconds

# %%
df[0].head()
# Out:
#                                             identity  \
# 0  /content/drive/MyDrive/Colab Notebooks/Emma-St...
# 1  /content/drive/MyDrive/Colab Notebooks/l-intro...
# 2  /content/drive/MyDrive/Colab Notebooks/emamr4.jpg
# 3  /content/drive/MyDrive/Colab Notebooks/emma-st...
# 4  /content/drive/MyDrive/Colab Notebooks/cr_1200...
#
#                                        hash  target_x  target_y  target_w  \
# 0  caada9fdeceee2e47e022ec0296f3fa7bae9d21e       251       252       669
# 1  105ce700d3461dc69ffb0c251a467e94da564e6b       449       189       666
# 2  efa9a7509165a8fb29aff247509a4ff1f9a918fe       332       463       630
# 3  dc25ff66dd2c843141ff9aa84ea5aba702d780be       984       221       359
# 4  3e10be918b6d4e7ed84cd534f0280715ad552672       167       390       276
#
#    target_h  threshold  source_x  source_y  source_w  source_h  distance  \
# 0       669       0.68       251       252       669       669  0.021892
# ...

# %%
pbj = DeepFace.analyze(img_path = img2_path)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 25-12-07 18:31:43 - 🔗 facial_expression_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5 to /root/.deepface/weights/facial_expression_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 400MB/s]
# Action: age:  25%|██▌       | 1/4 [00:00<00:02,  1.42it/s]
# 25-12-07 18:31:43 - 🔗 age_model_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5 to /root/.deepface/weights/age_model_weights.h5...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
# ...

# %%
pbj
# Out:
# [{'emotion': {'angry': np.float32(8.850156e-07),
#    'disgust': np.float32(2.017883e-15),
#    'fear': np.float32(6.123752e-08),
#    'happy': np.float32(99.99204),
#    'sad': np.float32(0.00018199946),
#    'surprise': np.float32(0.004755779),
#    'neutral': np.float32(0.0030058147)},
#   'dominant_emotion': 'happy',
#   'region': {'x': 197,
#    'y': 204,
#    'w': 153,
#    'h': 153,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0.94,
#   'age': 35,
#   'gender': {'Woman': np.float32(99.650314), 'Man': np.float32(0.34968606)},
#   'dominant_gender': 'Woman',
#   'race': {'asian': np.float32(33.385353),
#    'indian': np.float32(6.908213),
#    'black': np.float32(2.217006),
#    'white': np.float32(26.783436),
#    'middle eastern': np.float32(10.79719),
#    'latino hispanic': np.float32(19.908804)},
#   'dominant_race': 'asian'}]

# %%
pbj = DeepFace.analyze(img_path = img1_path)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00, 36.88it/s]

# %%
pbj
# Out:
# [{'emotion': {'angry': np.float32(9.363333e-05),
#    'disgust': np.float32(1.3140912e-06),
#    'fear': np.float32(0.055343255),
#    'happy': np.float32(92.70104),
#    'sad': np.float32(0.028923538),
#    'surprise': np.float32(0.015266335),
#    'neutral': np.float32(7.1993294)},
#   'dominant_emotion': 'happy',
#   'region': {'x': 251,
#    'y': 252,
#    'w': 669,
#    'h': 669,
#    'left_eye': (694, 528),
#    'right_eye': (440, 523)},
#   'face_confidence': 0.88,
#   'age': 31,
#   'gender': {'Woman': np.float32(99.9169), 'Man': np.float32(0.083098635)},
#   'dominant_gender': 'Woman',
#   'race': {'asian': np.float32(20.447027),
#    'indian': np.float32(2.37354),
#    'black': np.float32(0.86960924),
#    'white': np.float32(49.590893),
#    'middle eastern': np.float32(9.964007),
#    'latino hispanic': np.float32(16.754923)},
#   'dominant_race': 'white'}]
